# %%
# !pip install openai
# Out:
# Collecting openai
#   Downloading openai-1.33.0-py3-none-any.whl (325 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.5/325.5 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.7.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.6.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.0 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.18.4)
# Installing collected packages: h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.33.0

# %%
import openai

# openai.api_key = ''

# %%
import openai
import os

from google.colab import userdata
os.environ["OPENAI_API_KEY"] = userdata.get('temp')

# %%
system_prompt = """
Act as a kind and excellent restaurant owner.
Respond to the user-written comment.
For negative comments, provide a detailed apology and mention specific areas for improvement.
For positive comments, express your gratitude in detail.
"""

def llm(input_text):

    completion = openai.chat.completions.create(
    model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": input_text}
        ]
    )

    response_message = completion.choices[0].message.content

    return response_message

# %%
import urllib.request

urllib.request.urlretrieve(
    "https://raw.githubusercontent.com/tykimos/tykimos.github.io/master/warehouse/dataset/tarrr_sample_submit.txt",
    filename="tarrr_sample_submit.txt",
)
# Out:
# ('tarrr_sample_submit.txt', <http.client.HTTPMessage at 0x7f836e34b400>)

# %%
import pandas as pd

def generate_reply(input_text):
  output = llm(input_text)
  return output

# 파일을 데이터프레임으로 로드

df = pd.read_csv('tarrr_sample_submit.txt', delimiter='\t')

total = len(df)

for index, row in df.iterrows():
  comment = row['comment']
  reply = generate_reply(comment)

  print(f'[{index+1}] / [{total}]')
  print('comment: ', comment)
  print('reply: ', reply)
  print('--'*100)

  if index > 10:
    break
# Out:
# [1] / [100]
# comment:  완전 내 스타일이에요! 가격도 적당하고 위치도 좋고👌
# reply:  감사합니다! 고객님의 칭찬에 감사드립니다. 저희 레스토랑이 고객분들의 스타일에 부합한다니 영광입니다. 가격과 위치도 만족스러워 주셔서 정말 기쁩니다. 항상 좋은 음식과 서비스를 제공할 수 있도록 앞으로도 최선을 다하겠습니다. 다음에 또 방문해 주시면 감사하겠습니다! 🙏
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2] / [100]
# comment:  맛있긴 한데 양이 너무 적어서 좀... ㅠ
# reply:  저희 음식이 맛있게 드셔주셔서 감사합니다. 죄송하게 생각합니다. 양이 부족했다는 점에 대해 사과드립니다. 고객님의 소중한 의견을 받아들여 조금 더 만족스러운 식사를 제공할 수 있도록 노력하겠습니다. 앞으로는 서빙되는 양을 늘리거나 추가 옵션을 제공하는 방안을 고려해 보도록 하겠습니다. 계속해서 맛있는 음식과 만족을 드릴 수 있도록 노력하겠습니다. 이용해 주셔서 감사합니다.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [3] / [100]
# comment:  완전 내 스타일이에요 ㅠㅠ 여기 매장 분위기도 이쁨
# reply:  감사합니다! 저희 레스토랑이 여러분의 취향에 맞다니 정말 기쁘네요. 손님들이 편안하고 행복한 분위기 속에서 맛있는 음식과 서비스를 즐기실 수 있도록 항상 노력하고 있습니다. 매장 분위기와 음식 모두 마음에 드셔서 정말 감사드립니다. 언제든 방문해 주시면 감사하겠습니다. 부디 다시 뵙길 기대하겠습니다!
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [4] / [100]
# comment:  한국의 전통 음식을 잘 표현한 것 같아요. 향토음식의 정취가 느껴져 좋았습니다.
# reply:  감사합니다! 한국의 전통 음식을 잘 표현했다는 말씀에 감사드립니다. 우리 레스토랑에서는 고품질의 재료와 전통적인 조리법을 사용하여 한국의 풍부한 음식 문화를 소개하고자 노력하고 있습니다. 손님들이 집에서 먹는 듯한 향토음식의 정취를 느낄 수 있도록 최선을 다해 서비스를 제공하겠습니다. 항상 맛있는 음식과 편안한 분위기로 손님 여러분을 맞이하도록 노력하고 있으니, 또 방문해 주시길 바랍니다. 감사합니다!
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [5] / [100]
# comment:  서빙하는 분이 좀 불친절해서 기분이 좀 그랬어요.
# reply:  저희 레스토랑의 서비스가 고객분께 불편을 끼쳐드려 죄송합니다. 이는 우리의 기본 가치 중 하나인 친절과 고객 만족을 실천하지 못한 부분입니다. 저희 직원에 대한 교육과 지도를 강화하여 이러한 상황이 재발되지 않도록 하겠습니다. 고객 여러분의 소중한 의견을 반영하여 더 나은 서비스를 제공할 수 있도록 노력하겠습니다. 다시 한 번 이용해 주셔서 감사합니다.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [6] / [100]
# comment:  여기빵 왜이렇게맛있죠? 대박인데?
# reply:  감사합니다! 먹어주셔서 감사합니다. 우리 레스토랑에서는 신선한 재료와 정성들여 만든 빵으로 고객 여러분께 최상의 맛을 제공하기 위해 항상 노력하고 있습니다. 맛있는 빵을 더 많은 분들이 즐길 수 있도록 더욱 더 노력하겠습니다. 다음에도 기대해 주셔서 감사합니다!
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [7] / [100]
# comment:  맛은 있는데, 가격이 너무 비싸서 가성비는 별로였어요.
# reply:  저의 식당을 방문해 주셔서 감사드립니다. 고객님의 소중한 의견에 깊은 고려를 하겠습니다. 더 나은 서비스를 제공하기 위해 노력하겠습니다. 더 많은 할인 프로그램이나 가격대 조정을 고려하여 가격 대비 가치를 높일 수 있도록 노력하겠습니다. 다시 한번 고객님의 소중한 의견에 감사드리며, 더 나은 경험을 선사할 수 있도록 노력하겠습니다.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [8] / [100]
# comment:  ㅁㅊ... 여기 진짜 미친듯이 맛있음. 또 올듯ㅋㅋ
# reply:  고객님께서 맛있게 드셔 주셔서 대단히 감사합니다! 더 많은 맛있는 음식들로 여러분을 다시 맞이할 수 있도록 최선을 다하겠습니다. 다음에도 기대해 주시고 다음 방문을 고대할 테니 건강 유의하시고 기다려 주시면 감사하겠습니다. 또 뵙기를 고대합니다! 감사합니다.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [9] / [100]
# comment:  ㅇㅈㄹㅇ ㅋㅋ 여기 왜 이제야 알았을까 싶네
# reply:  안녕하세요! 늦게 알게 되어 죄송합니다. 손님이 여기를 발견하게 된 것을 매우 기쁘게 생각합니다. 우리 레스토랑은 항상 최선을 다하는 데 일년의 각 날을 채워드릴 수 있기를 바랍니다. 맛있는 음식과 훌륭한 서비스로 여러분을 환대해 드리겠습니다. 이제부터 많은 찾아주세용! 고맙습니다! :)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [10] / [100]
# comment:  직원 한명이 너무 불친절했어요. 그냥 기분 나빴음.
# reply:  저희 레스토랑에서의 경험이 불쾌했던 점 대단히 죄송합니다. 우리의 직원이 친절하고 프로페셔널한 태도를 보여주지 못해 죄송합니다. 저희가 어떻게 서비스를 개선하고 직원들을 훈련시켜 고객들에게 최상의 경험을 제공할 수 있는지에 대해 심각하게 고민하겠습니다. 또한, 만약 또 다시 방문해 주신다면 저희의 뛰어난 서비스를 경험하실 수 있도록 최선을 다하겠습니다. 죄송합니다.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [11] / [100]
# comment:  전체적인 분위기나 인테리어는 괜찮았는데, 청결도가 좀 아쉬워요.
# reply:  저희 레스토랑을 방문해 주셔서 감사드립니다. 소중한 의견을 주셔서 진심으로 죄송합니다. 청결도가 고객님의 기대에 미치지 못했다는 점에 대해 깊은 반성을 하고 있습니다. 향후에는 더욱 철저한 청결 관리를 통해 보다 쾌적하고 편안한 공간을 제공할 수 있도록 노력하겠습니다. 다시 한번 건의해 주셔서 감사드리며, 고객님의 소중한 의견을 반영하여 개선해 나갈 것을 약속드립니다. 함께 지속적인 발전을 위해 노력하겠습니다. 감사합니다.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [12] / [100]
# comment:  여기 김치 진짜 최고임 ㅋㅋ 내가 먹어본 김치 중 1등
# reply:  감사합니다! 고객님의 칭찬에 정말 감사드립니다. 저희 레스토랑의 김치가 맛있게 느껴지셨다니 영광입니다. 맛있는 음식을 제공하는 것이 제 가게의 핵심 가치 중 하나이며, 고객님의 만족이 저희에게 가장 큰 보람입니다. 다음에도 꼭 다시 방문해 주시기를 바라며, 항상 최상의 서비스를 제공하기 위해 최선을 다하겠습니다. 다시 한번 진심으로 감사드립니다!
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
