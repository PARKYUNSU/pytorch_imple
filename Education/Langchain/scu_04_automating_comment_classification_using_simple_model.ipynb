# %%
def simple_model(input_text):
  # 긍정적인 핵심어 및 ngram, 가중치
  positive_keywords = {
        "최고": 3,
        "추천": 3,
        "진짜 좋다": 2.5,
        "대박": 3,
        "극찬": 3,
        "아늑": 2,
        "좋았습니다": 2,
        "맛집": 3,
        "진리": 3,
        "핫플": 2.5,
        "맛있": 2.5,
        "오고 싶다": 2.5,
        "너무 친절해서": 2,
        "기분 좋게": 1.5,
        "분위기도 좋고": 1.5,
        "진짜 ㄹㅇ": 2,
        "맛있어요": 2,
        "좋은": 1,
        "왔는데": 1,
        "정말": 1.5,
        "좋아요": 1
    }

    # 부정적인 핵심어 및 n-grams와 가중치
  negative_keywords = {
        "실망": 3,
        "아쉽다": 2.5,
        "그냥 그래": 2.5,
        "실망스러움": 3,
        "음식이 너무": 2,
        "너무 짜서": 1.5,
        "그냥 그랬어요": 2,
        "기대 이하였습니다": 2,
        "늦게 나오고": 1.5,
        "별로였어요": 2,
        "이렇게": 1,
        "너무": 1
    }


  # 키워드 길이에 따라 정렬(내림차순)
  sorted_positive_keywords = sorted(positive_keywords.keys(),  key=len, reverse=True)
  sorted_negative_keywords = sorted(negative_keywords.keys(),  key=len, reverse=True)

  positive_score = 0
  negative_score = 0

  # 긍정 키워드 점수 계산
  for key in  sorted_positive_keywords:
    if key in input_text:
      positive_score += positive_keywords[key]
      input_text = input_text.replace(key, "")
      # 중복 점수 방지하기 위해 키워드를 텍스트에서 제거

  # 부정 키워드 점수 계산
  for key in  sorted_negative_keywords:
    if key in input_text:
      negative_score += negative_keywords[key]
      input_text = input_text.replace(key, "")
      # 중복 점수 방지하기 위해 키워드를 텍스트에서 제거

  # 결과 반환
  if positive_score > negative_score:
    return 1
  else:
    return 0

# %%
import urllib.request

urllib.request.urlretrieve(
    "https://raw.githubusercontent.com/tykimos/tykimos.github.io/master/warehouse/dataset/tarr_train.txt",
    filename="tarr_train.txt",
)
# Out:
# ('tarr_train.txt', <http.client.HTTPMessage at 0x7802f1c67fa0>)

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
def classify_text(input_text):
   output = simple_model(input_text)
   return output

# %%
# 파일을 데이터프레임으로 load

df = pd.read_csv('tarr_train.txt', delimiter='\t')
# delimiter='\t' (tab 기준으로 구분)
df.head()
# Out:
#    id                                      comment  label
# 0   1                  여기 음식은 언제 와도 실망시키지 않아요. 최고!      1
# 1   2  여기 라멘 진짜 ㄹㅇ 맛있어요. 국물이 진하고 면도 쫄깃해서 너무 좋았습니다.      1
# 2   3                     진짜 깔끔하고, 맛도 좋았어요. 추천합니다!      1
# 3   4                    왜 이렇게 유명한지 모르겠음ㅋㅋ ㄹㅈㄷ 맛없음      0
# 4   5      인생 타르트를 여기서 만났어요❤️ 달지 않고 고소해서 정말 추천합니다!      1

# %%
actual_labels =[]
predicted_labels = []

for idx, row in df.iterrows():
  comment = row['comment']
  actual_label = row['label']
  predicted_label = classify_text(comment)

  actual_labels.append(actual_label)
  predicted_labels.append(predicted_label)

  print('comment: ', comment)
  print('actual_class: ', actual_label )
  print('predicted_class: ', predicted_label)
  print('--' * 100)
# Out:
# comment:  여기 음식은 언제 와도 실망시키지 않아요. 최고!
# actual_class:  1
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:

# actual_class:  1
# predicted_class:  1
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  어릴 땐 여기 자주 왔는데, 맛이 변한 것 같아 아쉽네요.
# actual_class:  0
# predicted_class:  1
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  헉, 먹어본 스테이크 중에서 탑3 안에 드는 거 같아용! 👍
# actual_class:  1
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  신선한 재료와 특별한 레시피로 만든 음식이 정말 인상적이었어요!
# actual_class:  1
# predicted_class:  1
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  확실히 광고랑은 다르네요. 기대가 너무 컸나 봅니다. 그냥 그래요.
# actual_class:  0
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  서비스만 좋았다면 별 5개를 줬을텐데, 아쉽습니다.
# actual_class:  0
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  음식이 너무 짜서 다 먹지 못했어요.
# actual_class:  0
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  어릴 때 자주 가던 집인데, 여전히 그 맛 그대로네요. 추억이 새록새록.
# actual_class:  1
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  진짜 맛있어서 포장까지 했습니다!
# actual_class:  1
# predicted_class:  1
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  요즘 아이들이 좋아할만한 음식이 별로 없더라구요. 좀 아쉬워요.
# actual_class:  0
# predicted_class:  0
# ...
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  음... 리뷰보고 기대했는데, 그냥 그래요.
# actual_class:  0
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  주방에서 무슨 소리가 계속 나던데 조금 시끄러웠어요.
# actual_class:  0
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  서비스 개선 좀 해주세요. 직원들 태도에 좀 놀랐네요.
# actual_class:  0
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  치킨 진짜 부드럽고 맛있어요. 또 시켜 먹을거에요!ㅋㅋㅋ
# actual_class:  1
# predicted_class:  1
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  너무 실망이에요. 여기 리뷰 좋아서 왔는데 음식도 늦게 나오고, 서비스도 별로더라고요. 전 다신 안 올 것 같아요.
# actual_class:  0
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  오늘 먹은 스테이크 중 최고!
# actual_class:  1
# predicted_class:  1
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  웨이터분들 태도가 너무 불친절해요. 다른 곳에서 먹을 걸 그랬나봐요. 음식도 그다지...
# actual_class:  0
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  분위기, 맛, 서비스 모두 훌륭해요! 다만, 주차공간이 좀 협소해요ㅠㅠ
# actual_class:  1
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  햄버거 bun이 너무 퍽퍽함.
# actual_class:  0
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  전 여기 팬케이크가 진짜 맛있더라고요! 부드럽고, 메이플 시럽이 딱!
# actual_class:  1
# predicted_class:  1
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  리뷰 보고 왔는데, 왜 이렇게 평이 좋은지 모르겠어요. 저는 별로였습니다.
# actual_class:  0
# predicted_class:  1
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  냉면 국물이 아주 시원하고 맛있었어요! 여름에 와서 먹으면 좋을 것 같아요.
# actual_class:  1
# predicted_class:  1
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  여긴 왜 이렇게 사람이 많아요? 대기 시간 너무 길어요...
# actual_class:  0
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  닭갈비 매콤하고 양도 푸짐해요! 여기 오면 항상 주문하는 메뉴에요.
# actual_class:  1
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  와, 여기 새로 생긴 메뉴 진짜 대박이에요!! 가격도 괜찮고 맛도 좋아요!
# actual_class:  1
# predicted_class:  1
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  음료는 좋은데, 디저트가 너무 달아서 별로였어요.
# actual_class:  0
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  음... 여기 리뷰 왜 이래? 전 다시는 안 올 거 같아요.
# actual_class:  0
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  직원들이 너무 친절해서 기분 좋게 먹고 왔습니다.
# actual_class:  1
# predicted_class:  1
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  마지막 방문 후로 퀄리티가 많이 떨어진 것 같아요. 아쉬워요.
# actual_class:  0
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  와! 진짜 너무 맛있어요! 또 올게요!!
# actual_class:  1
# predicted_class:  1
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  테이블 정리가 안 되어 있어서 조금 기다렸어요. 그래도 음식은 맛있었습니다.
# actual_class:  1
# predicted_class:  1
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  너무 시끄러워서 밥 먹는데 집중이 안 됐어요.
# actual_class:  0
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  주문한 음식 나오는 데 1시간 걸렸어요. 이해가 안 가네요.
# actual_class:  0
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  요즘 여기가 제 인생 맛집이에요!
# actual_class:  1
# predicted_class:  1
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  먹다 남긴 음식까지 포장해 주셔서 감사했습니다.
# actual_class:  1
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  와 진짜 무슨 맛이 이래... 절대 안 오세요.
# actual_class:  0
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  파스타가 살짝 덜 익었던 거 같아요. 그래도 소스는 괜찮았습니다.
# actual_class:  1
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  내 돈 주고 먹기엔 너무 아까웠어요.
# actual_class:  0
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  저번에 왔을 때보다 서비스가 향상된 거 같아요! 계속 이렇게 유지해 주세요.
# actual_class:  1
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  여긴 언제 와도 만족해요! 오늘도 최고였어요.
# actual_class:  1
# predicted_class:  1
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  이런.. 주문 잘못 가져와서 다시 기다렸어요.
# actual_class:  0
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  소스가 좀 짜긴한데 고기는 부드럽고 좋아요~! 물 좀 더 주셨으면...
# actual_class:  1
# predicted_class:  1
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  이 가격에 이 퀄리티? 진짜 대박이다... 추천합니다!!!
# actual_class:  1
# predicted_class:  1
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  직원분이 주문을 잘못 받아와서 황당했는데, 바로 수정해 주셔서 감사해요!
# actual_class:  1
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  여긴 왜 이렇게 사람이 많은지 모르겠네요... 전 별로였어요. ㅠㅠ
# actual_class:  0
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  전 좀 매웠는데 친구는 딱 좋다고 하더라고요. 맵기 조절 가능하면 좋을 것 같아요.
# actual_class:  0
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  가게 안이 너무 어두워서 메뉴판 보기 힘들었어요. 조명 좀 밝게 해주세요!
# actual_class:  0
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  진짜 여기 짜장면 대박... 근데 짬뽕은 그냥 그래요 ㅋㅋ
# actual_class:  1
# predicted_class:  1
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  와... 생각보다 맛있네?!? 대 pleasantly surprised!!
# actual_class:  1
# predicted_class:  1
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  음식은 그럭저럭인데 화장실 청결 상태가 안 좋더라고요... 주의하세요.
# actual_class:  0
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  포장할 때 누락된 게 있어서 짜증났어요. 확인 잘 해주세요!
# actual_class:  0
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  여기 애프터눈 티세트? 진짜 대박입니다. 데이트하기 좋아요!
# actual_class:  1
# predicted_class:  1
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  음료는 별로였지만 디저트는 괜찮았어요!
# actual_class:  1
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  음식 나올 때까지 기다리는 시간이 너무 길어요. 개선 필요!
# actual_class:  0
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  너무 시끄러워서 이야기하기 힘들었네요. 다음에는 조용한 곳으로 부탁드려요.
# actual_class:  0
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  볶음밥 진짜 최고! 여긴 볶음밥 파는 곳이지, 안 그래요?ㅋㅋ
# actual_class:  1
# predicted_class:  1
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  음식 사진 찍기 좋아요. 인스타에 올릴 만해요!
# actual_class:  1
# predicted_class:  1
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  이런... 예약했는데 자리가 없다니요? 전 다신 안 올 거에요.
# actual_class:  0
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  맛은 있어요, 근데 가격이 좀... 아니죠?
# actual_class:  0
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  피자 반죽이 너무 특이해서 별로였어요. 소스는 괜찮았는데.
# actual_class:  0
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  다 좋은데, 음악 볼륨만 좀 낮추면 완벽할 것 같아요!
# actual_class:  1
# predicted_class:  1
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  와우! 여기 라떼아트 진짜 예술이네요. 인스타갬성!!
# actual_class:  1
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  처음 와봤는데, 여기 분위기도 좋고 음식도 맛있어요. 좋은 경험이었어요!
# actual_class:  1
# predicted_class:  1
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  음... 여기 리뷰 왜 이래? 사진으로 봤을 때랑 너무 다르네요.
# actual_class:  0
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  직원들이 너무 친절해서 기분 좋게 먹고 왔습니다. 굿굿!
# actual_class:  1
# predicted_class:  1
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# comment:  제 입맛엔 안 맞았어요. 다른 분들은 괜찮았을지 모르겠지만...
# actual_class:  0
# predicted_class:  0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# 정확도 계산
accuracy = accuracy_score(actual_labels, predicted_labels)
# y_real, y_pred 비교 (cost 줄이는 게 우리의 목표)

print(f"Accuracy: {accuracy*100:.2f}%")

print(set(actual_labels))
print(set(predicted_labels))

# Confusion matrix 계산
cm = confusion_matrix(actual_labels, predicted_labels, labels=[1, 0])
# Confusion matrix 표현
print("\nConfusion Matrix:")
print("         Predicted:")
print("         긍정    부정")
print("Actual")
print("긍정      {:<5}  {:<5}".format(cm[0][0], cm[0][1]))
print("부정      {:<5}  {:<5}".format(cm[1][0], cm[1][1]))
# Out:
# Accuracy: 76.33%
# {0, 1}
# {0, 1}
#
# Confusion Matrix:
#          Predicted:
#          긍정    부정
# Actual
# 긍정      100    62
# 부정      9      129

# %%
urllib.request.urlretrieve(
    "https://raw.githubusercontent.com/tykimos/tykimos.github.io/master/warehouse/dataset/tarr_sample_submit.txt",
    filename="tarr_sample_submit.txt",
)
# Out:
# ('tarr_sample_submit.txt', <http.client.HTTPMessage at 0x7802b67faa10>)

# %%
df_submit = pd.read_csv('tarr_sample_submit.txt', delimiter='\t')
df_submit
# Out:
#      id                                            comment  label
# 0     1                      완전 내 스타일이에요! 가격도 적당하고 위치도 좋고👌      0
# 1     2                            맛있긴 한데 양이 너무 적어서 좀... ㅠ      0
# 2     3                       완전 내 스타일이에요 ㅠㅠ 여기 매장 분위기도 이쁨      0
# 3     4       한국의 전통 음식을 잘 표현한 것 같아요. 향토음식의 정취가 느껴져 좋았습니다.      0
# 4     5                        서빙하는 분이 좀 불친절해서 기분이 좀 그랬어요.      0
# ..  ...                                                ...    ...
# 95   96                     가성비 최고! 이 가격에 이런 맛은 정말 만족스러워요.      0
# 96   97                         와... 여기김치... 말도안됨... ㅁㅊ...      0
# 97   98                       주문한 지 40분 넘게 기다려서 음식 나왔네요...      0
# 98   99                      아이들이랑 왔는데, 키즈 메뉴도 생각보다 맛있었어요!      0
# 99  100  오랜만에 외식을 했는데, 이런 결과를 보게 될 줄은 몰랐네요. 음식도 별로고, 서비...      0
#
# [100 rows x 3 columns]

# %%
predicted_labels = []

# 각 row 를 순회하면서 코멘트를 분류
for index, row in df_submit.iterrows():
  comment = row['comment']
  predicted_label = classify_text(comment)
  predicted_labels.append(predicted_label)

# 예측된 레이블 >> 데이터프레임에 추가
df_submit['label'] = predicted_labels

# 결과를 저장
df_submit
# Out:
#      id                                            comment  label
# 0     1                      완전 내 스타일이에요! 가격도 적당하고 위치도 좋고👌      0
# 1     2                            맛있긴 한데 양이 너무 적어서 좀... ㅠ      1
# 2     3                       완전 내 스타일이에요 ㅠㅠ 여기 매장 분위기도 이쁨      0
# 3     4       한국의 전통 음식을 잘 표현한 것 같아요. 향토음식의 정취가 느껴져 좋았습니다.      1
# 4     5                        서빙하는 분이 좀 불친절해서 기분이 좀 그랬어요.      0
# ..  ...                                                ...    ...
# 95   96                     가성비 최고! 이 가격에 이런 맛은 정말 만족스러워요.      1
# 96   97                         와... 여기김치... 말도안됨... ㅁㅊ...      0
# 97   98                       주문한 지 40분 넘게 기다려서 음식 나왔네요...      0
# 98   99                      아이들이랑 왔는데, 키즈 메뉴도 생각보다 맛있었어요!      1
# 99  100  오랜만에 외식을 했는데, 이런 결과를 보게 될 줄은 몰랐네요. 음식도 별로고, 서비...      0
#
# [100 rows x 3 columns]

# %%
df_submit[['id','comment','label']].to_csv('tarr_my_submit.txt', sep='\t', index=False)

# %%
df_submit.head()
# Out:
#    id                                       comment  label
# 0   1                 완전 내 스타일이에요! 가격도 적당하고 위치도 좋고👌      0
# 1   2                       맛있긴 한데 양이 너무 적어서 좀... ㅠ      1
# 2   3                  완전 내 스타일이에요 ㅠㅠ 여기 매장 분위기도 이쁨      0
# 3   4  한국의 전통 음식을 잘 표현한 것 같아요. 향토음식의 정취가 느껴져 좋았습니다.      1
# 4   5                   서빙하는 분이 좀 불친절해서 기분이 좀 그랬어요.      0
