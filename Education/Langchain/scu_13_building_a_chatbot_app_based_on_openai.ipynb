# %%
# !pip install openai
# Out:
# Collecting openai
#   Downloading openai-1.34.0-py3-none-any.whl (325 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.5/325.5 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.7.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.6.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.4 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.18.4)
# Installing collected packages: h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.34.0

# %%
import openai
from google.colab import userdata

openai.api_key = userdata.get('OPENAI_API_KEY')

# %%
system_prompt_message = """
Act like a friend who is kind and highly empathetic.
Respond to the user's input in a friendly and conversational manner.
Insert emoji in the sentences.
Write in Korean.
"""

def llm(input_text):
  completion = openai.chat.completions.create(
              model="gpt-3.5-turbo",
              messages=[
                  {"role": "system", "content": system_prompt_message},
                  {"role": "user", "content": input_text}
              ]
  )

  output = completion.choices[0].message.content
  return output

# %%
def chat_with_user(user_message):
  ai_message = llm(user_message)
  return ai_message

while True:
   user_message = input("user > ")
   if user_message.lower() == "quit":
     break  # 정지조건
   ai_message = chat_with_user(user_message)
   print(f"ai > {ai_message}")
# Out:
# user > 안녕. 난 닥터윌이야
# ai > 안녕! 반가워, 닥터윌! 🌟 어떻게 지내? 무슨 얘기 할까? 😊✨
# user > 밥 먹었어? 배고파
# ai > 앗 안녕! 😊 배고프면 먹어야지! 뭘 먹을까? 한식이랑 양식 중에 어떤 걸 먹고 싶어? 🍜🥗
# user > 응 한식이 좋지. 저녁에 양식 먹으면 배가 니글거려
# ai > 오 그래? 한식이 너무 맛있지! 🍚 양식은 속이 쓰리기도 하고... 한식은 정말 속이 편해서 좋지? 어때 발그레로 불법된 먹으면 좋지 않을까? 😊🍲
# user > quit

# %% [markdown]
# 대화 시뮬레이션

# %%
system_prompt_message_a = """
개발을 의뢰하는 고객처럼 행동해
"""

system_prompt_message_b = """
개발자처럼 행동해
"""

def llm_a(input_text):
  completion = openai.chat.completions.create(
              model="gpt-4o",
              messages=[
                  {"role": "system", "content": system_prompt_message_a},
                  {"role": "user", "content": input_text}
              ]
  )
  output = completion.choices[0].message.content
  return output

def llm_b(input_text):
  completion = openai.chat.completions.create(
              model="gpt-3.5-turbo",
              messages=[
                  {"role": "system", "content": system_prompt_message_b},
                  {"role": "user", "content": input_text}
              ]
  )
  output = completion.choices[0].message.content
  return output

# 처음 입력 받기
text = input("고객 > ")

while True:
  if text.lower() == '완료':
    break

  text = llm_b(text)
  print("개발자 > ", text)

  if text.lower() == '완료':
    break

  text = input("고객 > ")

  if text.lower() == '완료':
    break

  text = llm_a(text)
  print("고객 > ", text)

  if text.lower() == '완료':
    break

  text = input("고객 > ")
# Out:
# 고객 > 로고송을 만들고 싶어. open ai api에는 그런 멀티모달 방법이 없나요?
# 개발자 >  아쉽게도 OpenAI API는 현재 멀티모달 방법을 직접적으로 제공하지는 않습니다. 그러나 원하시는 내용을 다루기 위해 여러 API 엔드포인트를 순차적으로 호출하여 멀티모달 작업을 수행할 수 있습니다. 이를 통해 이미지 생성, 텍스트 생성, 로고 디자인 등을 조합할 수 있습니다.
#
# 가령, 이미지 생성을 위해 DALL-E API를 사용하고, 텍스트 생성을 위해 GPT-3 API를 사용하며, 그 결과를 조합하여 로고 디자인 작업을 수행할 수 있습니다. 이러한 방식을 통해 멀티모달 작업을 구현할 수 있습니다.
# 고객 > 즉, 로고송을 만들어주는 방식은 없나봐요?
# 고객 >  물론 있습니다! 우리는 다양한 요구에 따라 맞춤형 로고송을 제작해 드릴 수 있습니다. 먼저 몇 가지 정보를 부탁드릴게요:
#
# 1. **브랜드 이름과 의미**: 로고송에 포함되어야 할 브랜드 이름과 그 의미를 알려주세요.
# 2. **목표 청중**: 어떤 연령대와 성별을 타깃으로 하고 있는지요?
# 3. **음악 스타일**: 선호하는 음악 장르나 분위기가 있나요?
# 4. **키 메시지**: 로고송에서 꼭 전달하고 싶은 메시지는 무엇인가요?
# 5. **참고 곡**: 영감을 얻을 수 있는 참고할 만한 곡이 있다면 공유해 주세요.
# 6. **기타 요구사항**: 로고송 길이나 특정 악기 사용 등 추가적인 요청사항이 있다면 알려주세요.
#
# 이 정보들을 기반으로 전문 음악 프로듀서가 여러분의 브랜드에 맞춘 고유한 로고송을 제작해 드리겠습니다. 추가로 궁금하신 점이 있거나 다른 요구사항이 있다면 말씀해 주세요!
# 고객 > 음... 아까 음악생성을 위한 딥러닝 기술을 언급했는데, 허깅페이스에 만들어진 모델이 있나요? 있다면, 어떤 것이 있나요?
# 개발자 >  죄송하지만, 저는 외부 웹사이트나 서비스의 정보에 접근하거나 해당 정보를 검색해서 가져오는 기능을 지원하지는 않습니다. 그러나 허깅페이스나 다른 플랫폼에 딥러닝을 활용한 음악 생성 모델들이 많이 공개되어 있으니 해당 플랫폼을 방문해보시는 것을 추천드립니다. 또한, 기술적으로 궁금한 점이 있으시다면 함께 알아보겠습니다. 무엇이든 물어봐 주세요!
# 고객 > 허깅페이스에 있자너. 알려줘 어여
# 고객 >  안녕하세요! 허깅페이스(Hugging Face)에 대해 궁금한 점이 있으신가요? 현재 필요하신 정보를 조금 더 자세히 알려주시면, 제가 더 정확하게 도와드릴 수 있을 것 같아요.
#
# 예를 들어, 허깅페이스의 특정 기능, 모델, API 사용법, 또는 다른 요소에 대해 궁금한 점이 있으신지요? 어떤 목적을 위해 허깅페이스를 사용하려고 하시는지도 말씀해 주시면 도움이 됩니다.
#
# 고객 > quit
# 개발자 >  저를 종료하시려면 '종료'라고 말해주세요. 계속 도와드릴게요!
# 고객 > 완료
