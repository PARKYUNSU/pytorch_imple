# %%
# !pip install openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.9/386.9 kB 13.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.2/325.2 kB 22.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.7 MB/s eta 0:00:00
# ...

# %%
import os
from openai import OpenAI

# OPENAI_API_KEY = 'API KEY 입력해 주세요.'
OPENAI_API_KEY = "input your key!"
os.environ['OPENAI_API_KEY'] = OPENAI_API_KEY

# %%
from google.colab import userdata

os.environ['OPENAI_API_KEY'] = userdata.get('onepm')

# %%
import base64

def load_image(image_path):
    with open(image_path, 'rb') as img_file:
        base64_image = base64.b64encode(img_file.read()).decode('utf-8')
    return base64_image

# base64 : binary data >> chunk (말뭉치 단위) 6bit
# binary data >> text
# image data >> 0-255
# rb : read binary data

# %%
client = OpenAI()

# %% [markdown]
# ### 241028 수정사항
#
# - 기존에 이미지를 업로드해서 보내는 방식이 deprecated 됨에 따라 코드를 일부 삭제

# %%
# https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Gfp-wisconsin-madison-the-nature-boardwalk.jpg/2560px-Gfp-wisconsin-madison-the-nature-boardwalk.jpg

image = 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Gfp-wisconsin-madison-the-nature-boardwalk.jpg/2560px-Gfp-wisconsin-madison-the-nature-boardwalk.jpg'

# %%
response = client.chat.completions.create(
  model="gpt-4o-mini",
  messages=[
    {
      "role": "user",
      "content": [
        {"type": "text", "text": "What’s in this image?"},
        {
          "type": "image_url",
          "image_url": {
            "url": image,
          },
        },
      ],
    }
  ],
  max_tokens=300,
)

# %%
response
# Out:
# ChatCompletion(id='chatcmpl-ANCy1mhheQgwwRhWvCXkQsbiXQxMY', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='The image features a scenic landscape with a wooden pathway leading through a lush field of tall green grass. In the background, there are trees and shrubs bordered by a clear sky with scattered clouds. The overall atmosphere appears serene and natural, suggesting this could be a nature reserve or a tranquil outdoor area.', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None))], created=1730094753, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier=None, system_fingerprint='fp_8bfc6a7dc2', usage=CompletionUsage(completion_tokens=59, prompt_tokens=36848, total_tokens=36907, completion_tokens_details=CompletionTokensDetails(audio_tokens=None, reasoning_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=None, cached_tokens=1024)))

# %%
response.choices[0]
# Out:
# Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='The image features a scenic landscape with a wooden pathway leading through a lush field of tall green grass. In the background, there are trees and shrubs bordered by a clear sky with scattered clouds. The overall atmosphere appears serene and natural, suggesting this could be a nature reserve or a tranquil outdoor area.', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None))

# %%
response.choices[0].message.content
# Out:
# 'The image features a scenic landscape with a wooden pathway leading through a lush field of tall green grass. In the background, there are trees and shrubs bordered by a clear sky with scattered clouds. The overall atmosphere appears serene and natural, suggesting this could be a nature reserve or a tranquil outdoor area.'

# %%
another_image = 'https://wikidocs.net/images/page/31379/transformer_from_encoder_to_decoder.PNG'

# %%
response = client.chat.completions.create(
  model="gpt-4o-mini",
  messages=[
    {
      "role": "user",
      "content": [
        {"type": "text", "text": "What’s in this image? Please describe it in korean"},
        {
          "type": "image_url",
          "image_url": {
            "url": image,
          },
        },
      ],
    }
  ],
  max_tokens=1024,
)

print(response.choices[0].message.content)
# Out:
# 이 이미지는 푸른 하늘과 구름이 있는 넓은 들판의 풍경을 보여줍니다. 중앙에는 나무로 만든 보도가 있어 풀밭을 따라 뻗어 있습니다. 풀은 짙은 녹색이며, 주변에는 나무와 관목들이 있습니다. 전체적으로 평화롭고 자연이 넘치는 분위기를 느낄 수 있습니다.
