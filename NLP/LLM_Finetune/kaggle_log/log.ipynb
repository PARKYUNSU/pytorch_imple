# %%
# !git clone --filter=blob:none --sparse https://github.com/PARKYUNSU/pytorch_imple.git
# %cd pytorch_imple
# !git sparse-checkout set NLP/LLM_Finetune
# Out:
# Cloning into 'pytorch_imple'...
# remote: Enumerating objects: 3930, done.
# remote: Counting objects: 100% (235/235), done.
# remote: Compressing objects: 100% (136/136), done.
# remote: Total 3930 (delta 162), reused 140 (delta 97), pack-reused 3695 (from 3)
# Receiving objects: 100% (3930/3930), 756.70 KiB | 18.92 MiB/s, done.
# Resolving deltas: 100% (1803/1803), done.
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (2/2), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 1 (from 1)
# Receiving objects: 100% (3/3), 3.32 KiB | 3.32 MiB/s, done.
# /usr/local/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# /kaggle/working/pytorch_imple
# remote: Enumerating objects: 8, done.
# ...

# %%
# !python /kaggle/working/pytorch_imple/NLP/LLM_Finetune/main.py
# Out:
# /usr/local/lib/python3.10/site-packages/torch_xla/__init__.py:253: UserWarning: `tensorflow` can conflict with `torch-xla`. Prefer `tensorflow-cpu` when using PyTorch/XLA. To silence this warning, `pip uninstall -y tensorflow && pip install tensorflow-cpu`. If you are in a notebook environment such as Colab or Kaggle, restart your notebook runtime afterwards.
#   warnings.warn(
# config.json: 100%|█████████████████████████████| 692/692 [00:00<00:00, 5.07MB/s]
# WARNING: Logging before InitGoogle() is written to STDERR
# E0000 00:00:1743258320.965167     232 common_lib.cc:612] Could not set metric server port: INVALID_ARGUMENT: Could not find SliceBuilder port 8471 in any of the 0 ports provided in `tpu_process_addresses`="local"
# === Source Location Trace: ===
# learning/45eac/tfrc/runtime/common_lib.cc:230
# model.safetensors: 100%|████████████████████| 4.17G/4.17G [00:12<00:00, 343MB/s]
# tokenizer_config.json: 100%|███████████████| 50.9k/50.9k [00:00<00:00, 16.1MB/s]
# ...
