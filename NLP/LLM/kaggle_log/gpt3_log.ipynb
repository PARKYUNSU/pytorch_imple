# %%
# !git clone --filter=blob:none --sparse https://github.com/PARKYUNSU/pytorch_imple.git
# %cd pytorch_imple
# !git sparse-checkout set NLP/LLM
# Out:
# Cloning into 'pytorch_imple'...
# remote: Enumerating objects: 3869, done.
# remote: Counting objects: 100% (174/174), done.
# remote: Compressing objects: 100% (99/99), done.
# remote: Total 3869 (delta 119), reused 98 (delta 73), pack-reused 3695 (from 3)
# Receiving objects: 100% (3869/3869), 751.89 KiB | 19.28 MiB/s, done.
# Resolving deltas: 100% (1760/1760), done.
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (2/2), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 1 (from 1)
# Receiving objects: 100% (3/3), 3.32 KiB | 3.32 MiB/s, done.
# /kaggle/working/pytorch_imple
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 18 (delta 1), reused 13 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (18/18), 2.25 MiB | 21.57 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# !python /kaggle/working/pytorch_imple/NLP/LLM/main.py --model pre-norm
# Out:
# cleaned_02 Harry Potter and the Chamber of Secrets.txt 488771 characters
# # of tokens in txt: 130520
# Epoch 1/100: 100%|█| 254/254 [02:16<00:00,  1.86it/s, loss=11, tokens_seen=4096]
# Epoch: 1, Average Loss: 4.404057423899493
# Epoch 2/100: 100%|████████████████████████████| 254/254 [02:17<00:00,  1.85it/s]
# Epoch: 2, Average Loss: 2.246043414581479
# Epoch 3/100: 100%|████████████████████████████| 254/254 [02:17<00:00,  1.85it/s]
# Epoch: 3, Average Loss: 0.8100214579443293
# Epoch 4/100: 100%|█| 254/254 [02:17<00:00,  1.84it/s, loss=0.376, tokens_seen=4.
# Epoch: 4, Average Loss: 0.3941969830454804
# Epoch 5/100: 100%|████████████████████████████| 254/254 [02:17<00:00,  1.84it/s]
# Epoch: 5, Average Loss: 0.3051821598856468
# Epoch 6/100: 100%|████████████████████████████| 254/254 [02:17<00:00,  1.84it/s]
# Epoch: 6, Average Loss: 0.27052837070517655
# Epoch 7/100: 100%|████████████████████████████| 254/254 [02:18<00:00,  1.84it/s]
# Epoch: 7, Average Loss: 0.2524855890142636
# ...
